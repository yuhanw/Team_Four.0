# %% [markdown]
# In this notebook, you'll perform the actual analysis of the data stored in the directory
#
#     ./data/cleaned
#
# If the data is not ready yet (e.g. the other members of the team in charge of cleaning the data are not done yet), you may want to simulate cleaned data in the form you want them to be in order to perform the analysis. This may also help you data cleaning team to come up with the rigth data frame.
# If you choose to do so, store your simulated data into the directory
#
#     ./data/simulated
#
# Having performed analysis of simulated data may help you with the analysis of the actual data, since you will be able to notice deviations between the real and simulated data, which may be worth explaining and investigating further.
#
# The graphics your going to produce as a result of your analysis should be store in the directory:
#
#
#     ./visualization

# %% [markdown]
# ##Team members responsible for this notebook:
#
# List the team members contributing to this notebook, along with their responsabilities:
#
# * team member 1 **name**: team member 1 **responsabilities**
# * team member 2 **name**: team member 2 **responsabilities**
# * etc.
#
# I advise you to work at least in pairs for each project notebook, as you did for the homework assignments. Of course, all team members may participate to each notebook.

# %%
# %load_ext rmagic

# %%
# %%bash
# cd ../data1/cleaned
# ls
# Out:
# age2013.csv
# agecal.csv
# gen2013.csv
# gencal.csv
# race2013.csv
# racecal.csv

# %% [markdown]
# ### Part A

# %% [markdown]
# We are first working on the 2013 data by state.
#
# read csv into R.

# %%
# %%R
# gen2013=read.csv('../data1/cleaned/gen2013.csv',header=T)
# print(head(gen2013))
# Out:
#    X grp_code   state group emp_rate unemp_rate
# 1  2        2 Alabama   Men     59.2        7.0
# 2  3        3 Alabama Women     49.3        6.8
# 3 34        2  Alaska   Men     66.7        7.7
# 4 35        3  Alaska Women     59.6        5.3
# 5 60        2 Arizona   Men     60.4        8.2
# 6 61        3 Arizona Women     49.0        7.8

# %% [markdown]
# We need to compare the general employment rate between men and women. So we first generated 2 subsets with group name "Men" and "Women" only. Then we made a scatter plot to show the employment rates in different states.

# %%
# %%R  -w  800
# gen2013m=subset(gen2013, group=="Men")
# gen2013w=subset(gen2013, group=="Women")
#
# print(head(gen2013m$state))
# #not sure why we get those black dots, can anyone get rid of it?
# plot(gen2013m$state, gen2013m$emp_rate, col='blue', las=2, ylim=c(min(gen2013m$emp_rate,gen2013w$emp_rate), max(gen2013m$emp_rate,gen2013w$emp_rate)),
#      xlab='State Name', ylab='Employment Rate (percentage)', col.lab='blue')
# points(gen2013w$state, gen2013w$emp_rate, col='red')
# points(gen2013m$state, gen2013m$emp_rate, col='blue')
# legend('topleft', c('Employment Rate-Men','Employment Rate-Women'), col=c('blue','red'),pch=1)
# title('Employment Rate of Men and Women by States in 2013')
# Out:
# [1] Alabama    Alaska     Arizona    Arkansas   California Colorado
# 51 Levels: Alabama Alaska Arizona Arkansas California Colorado ... Wyoming

# %% [markdown]
# We also would like to know which states have the highest employment rates, and which states have the lowest employment rates.

# %%
# %%R
# print(list(gen2013m[which.max(gen2013m$emp_rate),],
# gen2013m[which.min(gen2013m$emp_rate),],
# gen2013w[which.max(gen2013w$emp_rate),],
# gen2013w[which.min(gen2013w$emp_rate),]))
# Out:
# [[1]]
#      X grp_code    state group emp_rate unemp_rate
# 55 866        2 Nebraska   Men     75.5          4
#
# [[2]]
#       X grp_code         state group emp_rate unemp_rate
# 97 1532        2 West Virginia   Men       55        7.8
#
# [[3]]
#       X grp_code        state group emp_rate unemp_rate
# 70 1094        3 North Dakota Women     66.2        2.3
#
# [[4]]
#       X grp_code         state group emp_rate unemp_rate
# 98 1533        3 West Virginia Women     45.9        5.1

# %% [markdown]
# And the employment rate difference between men and women.
#
# we first made a new dataframe gen2013mw, which combined Men and Women employment rates for the same state in the same row. Two new columns were generated: emp_rate_diff, and unemp_rate_diff.

# %%
# %%R
# names(gen2013m)[5:6]=paste(names(gen2013m)[5:6],'_m',sep='')
# names(gen2013w)[5:6]=paste(names(gen2013w)[5:6],'_w',sep='')
# print(gen2013m)
# Out:
#        X grp_code                state group emp_rate_m unemp_rate_m
# 1      2        2              Alabama   Men       59.2          7.0
# 3     34        2               Alaska   Men       66.7          7.7
# 5     60        2              Arizona   Men       60.4          8.2
# 7     93        2             Arkansas   Men       58.7          7.9
# 9    125        2           California   Men       64.0          9.1
# 11   158        2             Colorado   Men       69.3          6.9
# 13   191        2          Connecticut   Men       64.4          8.1
# 15   224        2             Delaware   Men       61.3          6.9
# 17   257        2 District of Columbia   Men       67.4          8.7
# 19   290        2              Florida   Men       61.3          7.5
# 21   323        2              Georgia   Men       65.3          7.3
# 23   356        2               Hawaii   Men       62.5          5.5
# 25   387        2                Idaho   Men       67.0          5.9
# 27   417        2             Illinois   Men       64.4          9.8
# 29   450        2              Indiana   Men       64.2          7.4
# 31   483        2                 Iowa   Men       70.6          5.0
# 33   516        2               Kansas   Men       68.8          5.7
# 35   549        2             Kentucky   Men       60.7          8.7
# 37   582        2            Louisiana   Men       61.8          7.3
# 39   614        2                Maine   Men       64.2          7.2
# 41   643        2             Maryland   Men       67.3          7.1
# 43   676        2        Massachusetts   Men       64.1          7.7
# 45   709        2             Michigan   Men       60.7          8.7
# 47   742        2            Minnesota   Men       70.9          5.3
# 49   775        2          Mississippi   Men       56.2          8.9
# 51   806        2             Missouri   Men       65.9          6.4
# 53   839        2              Montana   Men       63.9          6.2
# 55   866        2             Nebraska   Men       75.5          4.0
# 57   899        2               Nevada   Men       63.5          9.9
# 59   932        2        New Hampshire   Men       70.1          5.7
# 61   963        2           New Jersey   Men       64.9          8.7
# 63   996        2           New Mexico   Men       59.4          7.6
# 65  1027        2             New York   Men       61.9          8.2
# 67  1060        2       North Carolina   Men       62.7          8.1
# 69  1093        2         North Dakota   Men       75.3          3.3
# 71  1119        2                 Ohio   Men       62.3          8.3
# 73  1152        2             Oklahoma   Men       67.1          5.6
# 75  1184        2               Oregon   Men       60.4          8.4
# 77  1215        2         Pennsylvania   Men       64.0          8.1
# 79  1248        2         Rhode Island   Men       64.0          9.8
# 81  1281        2       South Carolina   Men       60.0          7.5
# 83  1314        2         South Dakota   Men       71.3          3.9
# 85  1343        2            Tennessee   Men       62.7          8.3
# 87  1376        2                Texas   Men       69.7          6.1
# 89  1409        2                 Utah   Men       75.1          4.4
# 91  1439        2              Vermont   Men       68.5          4.6
# 93  1466        2             Virginia   Men       68.3          5.6
# 95  1499        2           Washington   Men       64.5          7.4
# 97  1532        2        West Virginia   Men       55.0          7.8
# 99  1562        2            Wisconsin   Men       67.7          7.7
# 101 1595        2              Wyoming   Men       71.8          4.5

# %%
# %%R
# gen2013mw=merge(gen2013m,gen2013w, by='state')
# gen2013mw['emp_diff']=gen2013mw['emp_rate_m']-gen2013mw['emp_rate_w']
# gen2013mw['unemp_diff']=gen2013mw['unemp_rate_m']-gen2013mw['unemp_rate_w']
# gen2013mw=subset(gen2013mw, select=c(state,emp_rate_m,unemp_rate_m,emp_rate_w,unemp_rate_w,emp_diff, unemp_diff))
# print(head(gen2013mw))
# Out:
#        state emp_rate_m unemp_rate_m emp_rate_w unemp_rate_w emp_diff
# 1    Alabama       59.2          7.0       49.3          6.8      9.9
# 2     Alaska       66.7          7.7       59.6          5.3      7.1
# 3    Arizona       60.4          8.2       49.0          7.8     11.4
# 4   Arkansas       58.7          7.9       47.6          7.8     11.1
# 5 California       64.0          9.1       50.8          8.6     13.2
# 6   Colorado       69.3          6.9       58.0          6.2     11.3
#   unemp_diff
# 1        0.2
# 2        2.4
# 3        0.4
# 4        0.1
# 5        0.5
# 6        0.7

# %% [markdown]
# Make a scatter plot to see the employment difference. We can clearly see that for all states, the difference is positive, which suggests that men are employed more than women. To see this for sure, we will run t-tests to test whether the difference is statistically significant.
#
# Similarly, we made a plot too show the unemployment rate difference. In most states, the unemployment of men is a few percentage higher then women. (...discribe the graph)

# %%
# %%R   -w 800
# plot(gen2013mw$state, gen2013mw$emp_diff, col='blue', las=2, ylim=c(min(gen2013mw$emp_diff), max(gen2013mw$emp_diff)), xlab='State Name', ylab='Employment Rate Difference (Percentage)', col.lab='blue')
# title('Employment Rate Difference in 2013')
# plot(gen2013mw$state, gen2013mw$unemp_diff, col='blue', las=2, ylim=c(min(gen2013mw$unemp_diff), max(gen2013mw$unemp_diff)), xlab='State Name', ylab='Unmployment Rate Difference (Percentage)', col.lab='blue')
# title('Unmployment Rate Difference in 2013')

# %% [markdown]
# see which state has the highest and lowest employment difference. Do the same for unemployment rate.

# %%
# %%R
# print(list(gen2013mw[which.max(gen2013mw$emp_diff),],
# gen2013mw[which.min(gen2013mw$emp_diff),],
#           gen2013mw[which.max(gen2013mw$unemp_diff),],
# gen2013mw[which.min(gen2013mw$unemp_diff),]))
# Out:
# [[1]]
#    state emp_rate_m unemp_rate_m emp_rate_w unemp_rate_w emp_diff unemp_diff
# 45  Utah       75.1          4.4       56.9          4.4     18.2          0
#
# [[2]]
#    state emp_rate_m unemp_rate_m emp_rate_w unemp_rate_w emp_diff unemp_diff
# 20 Maine       64.2          7.2         58          6.2      6.2          1
#
# [[3]]
#            state emp_rate_m unemp_rate_m emp_rate_w unemp_rate_w emp_diff
# 49 West Virginia         55          7.8       45.9          5.1      9.1
#    unemp_diff
# 49        2.7
#
# [[4]]
#      state emp_rate_m unemp_rate_m emp_rate_w unemp_rate_w emp_diff unemp_diff
# 11 Georgia       65.3          7.3       50.7          9.3     14.6         -2

# %% [markdown]
# run a one-sample t-test to see whether we can reject the null hypothesis of "Men and women have the same employment rate", by comparing the employment rate with 0.
#
# do the same for unemployment difference.

# %%
# %%R
# print(t.test(gen2013mw$emp_diff, mu=0))
# print(t.test(gen2013mw$unemp_diff, mu=0))
# Out:
# 	One Sample t-test
#
# data:  gen2013mw$emp_diff
# t = 28.4945, df = 50, p-value < 2.2e-16
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#   9.65233 11.11630
# sample estimates:
# mean of x
#  10.38431
#
#
# 	One Sample t-test
#
# data:  gen2013mw$unemp_diff
# t = 5.1914, df = 50, p-value = 3.826e-06
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#  0.3738681 0.8457398
# sample estimates:
# mean of x
# 0.6098039

# %% [markdown]
# from what we get from the t-tests, we can reject the null hypotheses, and say that men has much higher employment rate, while lower unemployment rate, than women.

# %% [markdown]
# **Make maps to see the unemployment rate difference and employment rate difference between men and women in states in 2013**

# %% [markdown]
#  We need use packages "map" and "ggplot2" to make maps

# %%
# %%R
# install.packages("map")
# install.packages("ggplot2")
# Out:
# Installing package into ‘/home/oski/R/i686-pc-linux-gnu-library/3.0’
# (as ‘lib’ is unspecified)
# Installing package into ‘/home/oski/R/i686-pc-linux-gnu-library/3.0’
# (as ‘lib’ is unspecified)
# trying URL 'http://cran.cnr.Berkeley.edu/src/contrib/ggplot2_0.9.3.1.tar.gz'
# Content type 'application/x-gzip' length 2330942 bytes (2.2 Mb)
# opened URL
# ==================================================
# downloaded 2.2 Mb
#
#
# The downloaded source packages are in
# 	‘/tmp/RtmpBa3IQW/downloaded_packages’

# %%
# %%R
# require(ggplot2)
# require(maps)

# %% [markdown]
# Make a dataframe about an ordered list of longitude and latitude points that outlines each US state

# %%
# %%R
# us_state_map=map_data('state')
# print(head(us_state_map))
# Out:
#        long      lat group order  region subregion
# 1 -87.46201 30.38968     1     1 alabama      <NA>
# 2 -87.48493 30.37249     1     2 alabama      <NA>
# 3 -87.52503 30.37249     1     3 alabama      <NA>
# 4 -87.53076 30.33239     1     4 alabama      <NA>
# 5 -87.57087 30.32665     1     5 alabama      <NA>
# 6 -87.58806 30.32665     1     6 alabama      <NA>

# %% [markdown]
# Name unemp_diff as a dataframe with states and difference between unemployment rate of men and women in states in 2013

# %%
# %%R
# unemp_diff=gen2013mw["unemp_diff"]
# B=tolower(unname(unlist(gen2013mw["state"])))#lowercase states
# unemp_diff["region"]=B#use name "region" instead of "state"
# print(head(unemp_diff))
# Out:
#   unemp_diff     region
# 1        0.2    alabama
# 2        2.4     alaska
# 3        0.4    arizona
# 4        0.1   arkansas
# 5        0.5 california
# 6        0.7   colorado

# %% [markdown]
# Merge our dataframe of  unemp_difference into the map data, and sort it agian

# %%
# %%R
# map_data1=merge(us_state_map,unemp_diff,by="region",all.unemp_diff=T)
# map_data1=map_data1[order(map_data1$order), ]
# print(head(map_data1))
# Out:
#    region      long      lat group order subregion unemp_diff
# 1 alabama -87.46201 30.38968     1     1      <NA>        0.2
# 2 alabama -87.48493 30.37249     1     2      <NA>        0.2
# 3 alabama -87.52503 30.37249     1     3      <NA>        0.2
# 4 alabama -87.53076 30.33239     1     4      <NA>        0.2
# 5 alabama -87.57087 30.32665     1     5      <NA>        0.2
# 6 alabama -87.58806 30.32665     1     6      <NA>        0.2

# %% [markdown]
# We generate the map and color states according the unemployment rate difference between men and women in states in 2013

# %%
# %%R
# unemp_difference=unname(unlist(map_data1["unemp_diff"]))
# print(qplot(long,lat , data=map_data1, geom="polygon", group=group, fill=unemp_difference)
#       + labs(x="", y="")+theme_bw()+ggtitle("Unemployment Rate Difference between Men and Women in 2013")
#       +theme(legend.position="bottom", legend.direction="horizontal"))

# %% [markdown]
# We generate a similar map for employment rate difference between men and women in 2013 as we have done above

# %%
# %%R
# emp_diff=gen2013mw["emp_diff"]
# B=tolower(unname(unlist(gen2013mw["state"])))#lower case the state
# emp_diff["region"]=B
# map_data2=merge(us_state_map,emp_diff,by="region",all.emp_diff=T)
# map_data2=map_data2[order(map_data2$order), ]
# emp_difference=unname(unlist(map_data2["emp_diff"]))
# print(qplot(long,lat , data=map_data2, geom="polygon", group=group, fill=emp_difference)
#       + labs(x="", y="")+theme_bw()+ggtitle("Employment Rate Difference between Men and Women in 2013")
#       +theme(legend.position="bottom", legend.direction="horizontal"))

# %% [markdown]
# ### Now we analyze the gender discrimination of all the states based on various age groups.

# %%
# %%R
#
# age2013=read.csv('../data1/cleaned/age2013.csv',header=T)
# i=sapply(age2013, is.factor)
# print(i)
# age2013[i]=lapply(age2013[i],as.character)
# age2013=age2013[complete.cases(age2013),]
#
# A1=subset(age2013,grp_code==26|grp_code==33)
# A2=subset(age2013,grp_code==27|grp_code==34)
# A3=subset(age2013,grp_code==28|grp_code==35)
# A4=subset(age2013,grp_code==29|grp_code==36)
# A5=subset(age2013,grp_code==30|grp_code==37)
# A6=subset(age2013,grp_code==31|grp_code==38)
# A7=subset(age2013,grp_code==32|grp_code==39)
# A=list(A1,A2,A3,A4,A5,A6,A7)
#
# print(head(A))
# Out:
#          X   grp_code      state      group   emp_rate unemp_rate
#      FALSE      FALSE       TRUE       TRUE      FALSE      FALSE
# [[1]]
#        X grp_code                state                 group emp_rate
# 1     19       26              Alabama   Men, 16 to 19 years     18.1
# 8     26       33              Alabama Women, 16 to 19 years     25.3
# 25    78       26              Arizona   Men, 16 to 19 years     24.3
# 32    85       33              Arizona Women, 16 to 19 years     20.4
# 39   111       26             Arkansas   Men, 16 to 19 years     21.3
# 52   143       26           California   Men, 16 to 19 years     17.6
# 59   150       33           California Women, 16 to 19 years     20.0
# 66   176       26             Colorado   Men, 16 to 19 years     25.3
# 73   183       33             Colorado Women, 16 to 19 years     36.0
# 80   209       26          Connecticut   Men, 16 to 19 years     23.7
# 87   216       33          Connecticut Women, 16 to 19 years     25.8
# 94   242       26             Delaware   Men, 16 to 19 years     25.5
# 101  249       33             Delaware Women, 16 to 19 years     29.7
# 108  275       26 District of Columbia   Men, 16 to 19 years     11.8
# 497 1170       26             Oklahoma   Men, 16 to 19 years     29.1
# 510 1200       26               Oregon   Men, 16 to 19 years     23.5
# 517 1207       33               Oregon Women, 16 to 19 years     27.2
# 524 1233       26         Pennsylvania   Men, 16 to 19 years     29.0
# 531 1240       33         Pennsylvania Women, 16 to 19 years     33.9
# 538 1266       26         Rhode Island   Men, 16 to 19 years     27.0
# 545 1273       33         Rhode Island Women, 16 to 19 years     35.3
# 552 1299       26       South Carolina   Men, 16 to 19 years     19.3
# 559 1306       33       South Carolina Women, 16 to 19 years     26.9
# 566 1328       26         South Dakota   Men, 16 to 19 years     45.5
# 573 1335       33         South Dakota Women, 16 to 19 years     48.5
# 580 1361       26            Tennessee   Men, 16 to 19 years     27.1
# 587 1368       33            Tennessee Women, 16 to 19 years     26.5
# 594 1394       26                Texas   Men, 16 to 19 years     27.4
# 601 1401       33                Texas Women, 16 to 19 years     25.7
# 608 1424       26                 Utah   Men, 16 to 19 years     37.6
# 615 1431       33                 Utah Women, 16 to 19 years     44.9
# 622 1451       26              Vermont   Men, 16 to 19 years     34.6
# 629 1458       33              Vermont Women, 16 to 19 years     38.9
# 636 1484       26             Virginia   Men, 16 to 19 years     26.8
# 643 1491       33             Virginia Women, 16 to 19 years     28.2
# 650 1517       26           Washington   Men, 16 to 19 years     24.0
# 657 1524       33           Washington Women, 16 to 19 years     23.5
# 664 1547       26        West Virginia   Men, 16 to 19 years     19.5
# 671 1554       33        West Virginia Women, 16 to 19 years     19.4
# 678 1580       26            Wisconsin   Men, 16 to 19 years     38.5
# 685 1587       33            Wisconsin Women, 16 to 19 years     46.4
# 692 1611       26              Wyoming   Men, 16 to 19 years     41.0
# 699 1618       33              Wyoming Women, 16 to 19 years     46.7
#     unemp_rate
# 1         32.3
# 8         15.6
# 25        29.8
# 32        28.9
# 39        33.3
# 52        34.0
# 59        25.6
# 66        29.1
# 73        15.2
# 80        25.6
# 87        20.8
# 94        25.0
# 101       15.2
# 108       41.1
# 115       28.9
# 122       20.1
# 129       11.6
# 136       33.8
# 143       28.9
# 150       18.3
# 157       17.7
# 164       21.0
# 171       19.3
# 178       30.8
# 185       25.7
# 192       25.4
# 199       18.0
# 206       12.5
# 213       11.5
# 220       22.5
# 227       10.5
# 234       25.3
# 241       16.4
# 248       14.2
# 255       18.4
# 262       21.9
# 269       20.3
# 276       29.6
# 283       24.5
# 290       21.3
# 297       20.2
# 304       25.2
# 311       22.1
# 318       18.5
# 325       11.9
# 338       22.8
# 345       17.9
# 352       19.5
# 359       16.3
# 372        8.5
# 379       12.9
# 386       28.2
# 393       29.9
# 400       15.5
# 407       15.7
# 414       26.6
# 421       22.4
# 428       19.1
# 435       11.3
# 442       25.5
# 449       18.0
# 456       30.5
# 463       22.3
# 470        5.0
# 483       20.3
# 490       18.5
# 497       22.6
# 510       29.5
# 517       25.4
# 524       26.1
# 531       18.3
# 538       28.8
# 545       22.4
# 552       36.4
# 559       19.4
# 566       10.6
# 573       10.1
# 580       35.6
# 587       27.2
# 594       21.4
# 601       21.7
# 608       18.7
# 615       11.8
# 622       17.4
# 629       13.1
# 636       23.9
# 643       22.7
# 650       29.4
# 657       32.0
# 664       21.1
# 671       22.8
# 678       19.4
# 685       11.8
# 692       18.1
# 699       12.7
#
# [[2]]
#        X grp_code                state                 group emp_rate
# 2     20       27              Alabama   Men, 20 to 24 years     64.7
# 9     27       34              Alabama Women, 20 to 24 years     55.7
# 15    49       27               Alaska   Men, 20 to 24 years     70.6
# 20    54       34               Alaska Women, 20 to 24 years     61.5
# 26    79       27              Arizona   Men, 20 to 24 years     62.4
# 33    86       34              Arizona Women, 20 to 24 years     54.2
# 40   112       27             Arkansas   Men, 20 to 24 years     66.1
# 46   118       34             Arkansas Women, 20 to 24 years     53.0
# 53   144       27           California   Men, 20 to 24 years     58.9
# 60   151       34           California Women, 20 to 24 years     54.4
# 67   177       27             Colorado   Men, 20 to 24 years     68.3
# 74   184       34             Colorado Women, 20 to 24 years     64.4
# 81   210       27          Connecticut   Men, 20 to 24 years     64.0
# 88   217       34          Connecticut Women, 20 to 24 years     65.4
# 95   243       27             Delaware   Men, 20 to 24 years     61.5
# 102  250       34             Delaware Women, 20 to 24 years     63.0
# 109  276       27 District of Columbia   Men, 20 to 24 years     57.3
# 116  283       34 District of Columbia Women, 20 to 24 years     61.7
# 123  309       27              Florida   Men, 20 to 24 years     62.2
# 130  316       34              Florida Women, 20 to 24 years     61.7
# 137  342       27              Georgia   Men, 20 to 24 years     61.5
# 144  349       34              Georgia Women, 20 to 24 years     52.6
# 151  373       27               Hawaii   Men, 20 to 24 years     64.1
# 158  380       34               Hawaii Women, 20 to 24 years     56.8
# 165  403       27                Idaho   Men, 20 to 24 years     72.7
# 172  410       34                Idaho Women, 20 to 24 years     64.3
# 179  436       27             Illinois   Men, 20 to 24 years     63.1
# 186  443       34             Illinois Women, 20 to 24 years     55.9
# 193  469       27              Indiana   Men, 20 to 24 years     68.9
# 200  476       34              Indiana Women, 20 to 24 years     59.4
# 207  502       27                 Iowa   Men, 20 to 24 years     69.6
# 214  509       34                 Iowa Women, 20 to 24 years     75.8
# 221  535       27               Kansas   Men, 20 to 24 years     68.9
# 228  542       34               Kansas Women, 20 to 24 years     68.6
# 235  568       27             Kentucky   Men, 20 to 24 years     65.2
# 242  575       34             Kentucky Women, 20 to 24 years     59.0
# 249  600       27            Louisiana   Men, 20 to 24 years     63.8
# 256  607       34            Louisiana Women, 20 to 24 years     55.7
# 263  629       27                Maine   Men, 20 to 24 years     71.2
# 270  636       34                Maine Women, 20 to 24 years     70.3
# 277  662       27             Maryland   Men, 20 to 24 years     65.1
# 284  669       34             Maryland Women, 20 to 24 years     62.6
# 291  695       27        Massachusetts   Men, 20 to 24 years     57.0
# 298  702       34        Massachusetts Women, 20 to 24 years     60.6
# 305  728       27             Michigan   Men, 20 to 24 years     61.0
# 312  735       34             Michigan Women, 20 to 24 years     59.1
# 319  761       27            Minnesota   Men, 20 to 24 years     75.1
# 326  768       34            Minnesota Women, 20 to 24 years     76.2
# 693 1612       27              Wyoming   Men, 20 to 24 years     78.6
# 700 1619       34              Wyoming Women, 20 to 24 years     58.5
#     unemp_rate
# 2         15.0
# 9         13.2
# 15        10.1
# 20        10.1
# 26        17.5
# 33        14.3
# 40        15.9
# 46        15.4
# 53        16.0
# 60        13.8
# 67        13.1
# 74        10.2
# 81        12.1
# 88         8.7
# 95        15.7
# 102       11.2
# 109       15.3
# 116       10.2
# 123       12.2
# 130        9.2
# 137       13.6
# 144       15.9
# 151       12.1
# 158        7.7
# 165        8.6
# 172       11.6
# 179       16.0
# 186       15.6
# 193       11.8
# 200       13.3
# 207       12.1
# 214        4.4
# 221       11.5
# 228        8.4
# 235       15.7
# 242       13.5
# 249       15.3
# 256       12.4
# 263        9.9
# 270        8.4
# 277       12.6
# 284        8.1
# 291       18.3
# 298        9.0
# 305       15.2
# 312       15.4
# 319        8.7
# 326        5.9
# 332       24.2
# 339       18.4
# 346       12.6
# 353       10.0
# 360       11.2
# 366        5.2
# 373        7.8
# 380        6.8
# 387       15.1
# 394       11.9
# 401       13.4
# 408        7.7
# 415       15.1
# 422       12.3
# 429       11.5
# 436       10.3
# 443       15.9
# 450       11.6
# 457       16.1
# 464       16.9
# 471        5.7
# 477        4.0
# 484       16.9
# 491        9.3
# 498        8.4
# 504        7.9
# 511       15.2
# 518        9.3
# 525       14.6
# 532        9.9
# 539       15.9
# 546        9.0
# 553       12.9
# 560       13.1
# 567        7.5
# 574        6.6
# 581       13.8
# 588       13.3
# 595       11.1
# 602       10.3
# 609        6.3
# 616        6.1
# 623        7.0
# 630       10.9
# 637       13.3
# 644        9.0
# 651       14.9
# 658       10.2
# 665       12.1
# 672        9.2
# 679       13.3
# 686       10.6
# 693        5.7
# 700       10.5
#
# [[3]]
#        X grp_code                state                 group emp_rate
# 3     21       28              Alabama   Men, 25 to 34 years     79.2
# 10    28       35              Alabama Women, 25 to 34 years     65.3
# 16    50       28               Alaska   Men, 25 to 34 years     82.1
# 21    55       35               Alaska Women, 25 to 34 years     66.6
# 27    80       28              Arizona   Men, 25 to 34 years     77.8
# 34    87       35              Arizona Women, 25 to 34 years     65.3
# 41   113       28             Arkansas   Men, 25 to 34 years     85.3
# 47   119       35             Arkansas Women, 25 to 34 years     60.0
# 54   145       28           California   Men, 25 to 34 years     81.2
# 61   152       35           California Women, 25 to 34 years     64.6
# 68   178       28             Colorado   Men, 25 to 34 years     84.6
# 75   185       35             Colorado Women, 25 to 34 years     73.4
# 82   211       28          Connecticut   Men, 25 to 34 years     83.7
# 89   218       35          Connecticut Women, 25 to 34 years     72.5
# 96   244       28             Delaware   Men, 25 to 34 years     84.5
# 103  251       35             Delaware Women, 25 to 34 years     66.5
# 110  277       28 District of Columbia   Men, 25 to 34 years     83.7
# 117  284       35 District of Columbia Women, 25 to 34 years     76.9
# 124  310       28              Florida   Men, 25 to 34 years     79.7
# 131  317       35              Florida Women, 25 to 34 years     67.1
# 138  343       28              Georgia   Men, 25 to 34 years     79.7
# 505 1178       35             Oklahoma Women, 25 to 34 years     60.6
# 512 1202       28               Oregon   Men, 25 to 34 years     79.6
# 519 1209       35               Oregon Women, 25 to 34 years     69.9
# 526 1235       28         Pennsylvania   Men, 25 to 34 years     81.9
# 533 1242       35         Pennsylvania Women, 25 to 34 years     69.6
# 540 1268       28         Rhode Island   Men, 25 to 34 years     79.8
# 547 1275       35         Rhode Island Women, 25 to 34 years     67.7
# 554 1301       28       South Carolina   Men, 25 to 34 years     80.1
# 561 1308       35       South Carolina Women, 25 to 34 years     67.0
# 568 1330       28         South Dakota   Men, 25 to 34 years     90.7
# 575 1337       35         South Dakota Women, 25 to 34 years     81.7
# 582 1363       28            Tennessee   Men, 25 to 34 years     83.0
# 589 1370       35            Tennessee Women, 25 to 34 years     63.9
# 596 1396       28                Texas   Men, 25 to 34 years     85.1
# 603 1403       35                Texas Women, 25 to 34 years     63.4
# 610 1426       28                 Utah   Men, 25 to 34 years     90.2
# 617 1433       35                 Utah Women, 25 to 34 years     63.0
# 624 1453       28              Vermont   Men, 25 to 34 years     82.6
# 631 1460       35              Vermont Women, 25 to 34 years     75.4
# 638 1486       28             Virginia   Men, 25 to 34 years     85.4
# 645 1493       35             Virginia Women, 25 to 34 years     72.3
# 652 1519       28           Washington   Men, 25 to 34 years     84.1
# 659 1526       35           Washington Women, 25 to 34 years     68.7
# 666 1549       28        West Virginia   Men, 25 to 34 years     73.4
# 673 1556       35        West Virginia Women, 25 to 34 years     63.6
# 680 1582       28            Wisconsin   Men, 25 to 34 years     83.6
# 687 1589       35            Wisconsin Women, 25 to 34 years     77.1
# 694 1613       28              Wyoming   Men, 25 to 34 years     87.0
# 701 1620       35              Wyoming Women, 25 to 34 years     69.7
#     unemp_rate
# 3          7.2
# 10        10.3
# 16         8.2
# 21         6.4
# 27         8.8
# 34         5.5
# 41         5.9
# 47         6.4
# 54         9.1
# 61         8.0
# 68         7.1
# 75         5.6
# 82         7.7
# 89         8.1
# 96         6.3
# 103        8.7
# 110        6.8
# 117        7.1
# 124        8.2
# 131        7.2
# 138        7.9
# 145       10.6
# 152        4.6
# 159        4.0
# 166        6.3
# 173        8.5
# 180        8.0
# 187        7.7
# 194        7.4
# 201        9.3
# 208        4.3
# 215        3.8
# 222        6.1
# 229        5.2
# 236       10.8
# 243        7.4
# 250        9.7
# 257        7.4
# 264        9.6
# 271        6.7
# 278        5.7
# 285        5.8
# 292        6.8
# 299        8.1
# 306        8.6
# 313        8.6
# 320        5.0
# 327        4.3
# 333        7.0
# 340        8.0
# 347        5.5
# 354        6.3
# 361        5.1
# 367        4.1
# 374        4.0
# 381        5.4
# 388        7.7
# 395        9.0
# 402        4.2
# 409        4.1
# 416        9.9
# 423        7.1
# 430       10.3
# 437        8.7
# 444        7.0
# 451        7.4
# 458        7.1
# 465        7.9
# 472        3.2
# 478        1.7
# 485        7.7
# 492        7.4
# 499        6.2
# 505        8.4
# 512        9.9
# 519        6.0
# 526        8.6
# 533        8.2
# 540        9.6
# 547       10.4
# 554        8.7
# 561        8.5
# 681 1583       29            Wisconsin   Men, 35 to 44 years     87.7
# 688 1590       36            Wisconsin Women, 35 to 44 years     79.9
# 695 1614       29              Wyoming   Men, 35 to 44 years     91.6
# 702 1621       36              Wyoming Women, 35 to 44 years     73.5
#     unemp_rate
# 4          4.3
# 11         5.6
# 17         5.0
# 22         2.6
# 28         4.1
# 35         6.7
# 42         5.0
# 48         5.2
# 55         7.1
# 62         7.4
# 69         4.1
# 76         4.5
# 83         7.9
# 90         5.0
# 97         5.3
# 104        4.5
# 111        5.6
# 118        7.8
# 125        6.1
# 132        5.7
# 139        5.2
# 146        8.1
# 153        3.3
# 160        3.2
# 167        4.7
# 174        4.7
# 181        8.0
# 188        8.3
# 195        5.2
# 202        7.7
# 209        3.4
# 216        4.3
# 223        2.4
# 230        5.6
# 237        6.9
# 244        6.0
# 251        7.0
# 258        4.2
# 265        7.3
# 272        4.1
# 279        6.3
# 286        5.8
# 293        5.6
# 300        4.2
# 307        5.9
# 314        8.5
# 321        3.0
# 328        3.8
# 334        7.4
# 341        8.2
# 348        5.9
# 355        4.8
# 362        6.1
# 368        5.1
# 375        3.8
# 382        2.6
# 389        6.9
# 396        8.6
# 403        3.8
# 410        4.6
# 417        5.5
# 424        7.4
# 431        6.3
# 438        8.2
# 445        5.9
# 452        5.7
# 459        5.7
# 466        6.6
# 473        3.4
# 479        1.8
# 486        7.8
# 493        6.4
# 500        5.1
# 506        5.3
# 513        6.9
# 520        6.1
# 527        5.7
# 534        3.6
# 541        7.3
# 548        7.0
# 555        5.4
# 562        5.3
# 569        2.4
# 576        4.7
# 583        6.4
# 590        6.5
# 597        4.3
# 604        5.3
# 611        3.9
# 618        4.1
# 625        2.7
# 632        2.9
# 639        4.8
# 646        4.7
# 653        4.9
# 660        5.8
# 667        5.9
# 674        4.8
# 681        7.2
# 688        3.9
# 695        2.4
# 702        2.9
#
# [[5]]
#        X grp_code                state                 group emp_rate
# 5     23       30              Alabama   Men, 45 to 54 years     73.8
# 12    30       37              Alabama Women, 45 to 54 years     66.1
# 18    52       30               Alaska   Men, 45 to 54 years     83.1
# 23    57       37               Alaska Women, 45 to 54 years     73.8
# 29    82       30              Arizona   Men, 45 to 54 years     76.3
# 36    89       37              Arizona Women, 45 to 54 years     63.8
# 43   115       30             Arkansas   Men, 45 to 54 years     71.9
# 49   121       37             Arkansas Women, 45 to 54 years     67.8
# 56   147       30           California   Men, 45 to 54 years     81.8
# 63   154       37           California Women, 45 to 54 years     65.9
# 70   180       30             Colorado   Men, 45 to 54 years     85.8
# 77   187       37             Colorado Women, 45 to 54 years     75.4
# 84   213       30          Connecticut   Men, 45 to 54 years     79.5
# 91   220       37          Connecticut Women, 45 to 54 years     72.3
# 98   246       30             Delaware   Men, 45 to 54 years     79.5
# 105  253       37             Delaware Women, 45 to 54 years     69.4
# 112  279       30 District of Columbia   Men, 45 to 54 years     71.9
# 119  286       37 District of Columbia Women, 45 to 54 years     67.1
# 126  312       30              Florida   Men, 45 to 54 years     80.2
# 501 1174       30             Oklahoma   Men, 45 to 54 years     82.7
# 507 1180       37             Oklahoma Women, 45 to 54 years     68.5
# 514 1204       30               Oregon   Men, 45 to 54 years     77.6
# 521 1211       37               Oregon Women, 45 to 54 years     69.3
# 528 1237       30         Pennsylvania   Men, 45 to 54 years     80.6
# 535 1244       37         Pennsylvania Women, 45 to 54 years     70.3
# 542 1270       30         Rhode Island   Men, 45 to 54 years     80.9
# 549 1277       37         Rhode Island Women, 45 to 54 years     73.8
# 556 1303       30       South Carolina   Men, 45 to 54 years     75.0
# 563 1310       37       South Carolina Women, 45 to 54 years     67.8
# 570 1332       30         South Dakota   Men, 45 to 54 years     87.3
# 577 1339       37         South Dakota Women, 45 to 54 years     80.8
# 584 1365       30            Tennessee   Men, 45 to 54 years     74.8
# 591 1372       37            Tennessee Women, 45 to 54 years     68.1
# 598 1398       30                Texas   Men, 45 to 54 years     84.7
# 605 1405       37                Texas Women, 45 to 54 years     69.3
# 612 1428       30                 Utah   Men, 45 to 54 years     89.6
# 619 1435       37                 Utah Women, 45 to 54 years     68.8
# 626 1455       30              Vermont   Men, 45 to 54 years     86.0
# 633 1462       37              Vermont Women, 45 to 54 years     83.5
# 640 1488       30             Virginia   Men, 45 to 54 years     85.2
# 647 1495       37             Virginia Women, 45 to 54 years     74.0
# 654 1521       30           Washington   Men, 45 to 54 years     79.6
# 661 1528       37           Washington Women, 45 to 54 years     74.5
# 668 1551       30        West Virginia   Men, 45 to 54 years     70.6
# 675 1558       37        West Virginia Women, 45 to 54 years     60.5
# 682 1584       30            Wisconsin   Men, 45 to 54 years     85.4
# 689 1591       37            Wisconsin Women, 45 to 54 years     76.9
# 696 1615       30              Wyoming   Men, 45 to 54 years     86.3
# 703 1622       37              Wyoming Women, 45 to 54 years     74.2
#     unemp_rate
# 5          5.3
# 12         3.9
# 18         6.1
# 23         4.5
# 29         6.5
# 36         6.5
# 43         5.5
# 49         6.0
# 56         6.1
# 63         7.7
# 70         4.3
# 77         4.1
# 84         6.7
# 91         6.5
# 98         5.3
# 105        6.5
# 112       11.4
# 119        9.5
# 126        5.9
# 133        6.4
# 140        5.2
# 147        6.0
# 154        3.8
# 161        1.9
# 168        3.4
# 175        5.5
# 182        8.1
# 189        6.2
# 196        6.9
# 203        5.6
# 210        4.0
# 217        3.3
# 224        3.9
# 231        3.4
# 238        6.2
# 245        7.0
# 252        4.4
# 259        3.9
# 266        4.3
# 273        6.1
# 280        5.7
# 287        5.3
# 294        4.9
# 301        5.1
# 308        6.6
# 315        6.2
# 322        4.6
# 329        3.6
# 335        4.6
# 342        5.0
# 349        4.5
# 356        6.0
# 363        5.0
# 369        4.2
# 376        3.5
# 383        2.3
# 390        9.7
# 397        8.3
# 404        5.5
# 411        4.1
# 418        7.1
# 425        5.5
# 432        5.0
# 439        3.0
# 446        7.6
# 453        5.7
# 460        7.2
# 467        5.0
# 474        2.7
# 480        2.0
# 487        6.7
# 494        4.7
# 501        4.5
# 507        3.1
# 514        5.7
# 521        7.7
# 528        6.7
# 535        5.8
# 542        8.4
# 549        7.3
# 556        6.1
# 563        5.9
# 570        3.2
# 577        2.4
# 584        6.1
# 591        4.5
# 598        3.9
# 605        4.7
# 612        2.9
# 619        3.3
# 626        3.6
# 633        1.6
# 640        2.6
# 647        3.5
# 654        5.4
# 661        4.3
# 668        5.7
# 675        4.4
# 682        3.9
# 689        4.8
# 696        3.8
# 703        2.0
#
# [[6]]
#        X grp_code                state                 group emp_rate
# 6     24       31              Alabama   Men, 55 to 64 years     57.8
# 13    31       38              Alabama Women, 55 to 64 years     48.5
# 19    53       31               Alaska   Men, 55 to 64 years     65.9
# 24    58       38               Alaska Women, 55 to 64 years     60.9
# 30    83       31              Arizona   Men, 55 to 64 years     61.4
# 37    90       38              Arizona Women, 55 to 64 years     52.3
# 44   116       31             Arkansas   Men, 55 to 64 years     57.2
# 50   122       38             Arkansas Women, 55 to 64 years     46.1
# 57   148       31           California   Men, 55 to 64 years     65.3
# 64   155       38           California Women, 55 to 64 years     54.1
# 71   181       31             Colorado   Men, 55 to 64 years     72.2
# 78   188       38             Colorado Women, 55 to 64 years     60.7
# 85   214       31          Connecticut   Men, 55 to 64 years     71.0
# 92   221       38          Connecticut Women, 55 to 64 years     63.2
# 99   247       31             Delaware   Men, 55 to 64 years     63.3
# 106  254       38             Delaware Women, 55 to 64 years     53.8
# 113  280       31 District of Columbia   Men, 55 to 64 years     63.8
# 120  287       38 District of Columbia Women, 55 to 64 years     58.6
# 127  313       31              Florida   Men, 55 to 64 years     67.1
# 134  320       38              Florida Women, 55 to 64 years     56.5
# 141  346       31              Georgia   Men, 55 to 64 years     66.8
# 148  353       38              Georgia Women, 55 to 64 years     49.6
# 155  377       31               Hawaii   Men, 55 to 64 years     67.2
# 162  384       38               Hawaii Women, 55 to 64 years     60.3
# 169  407       31                Idaho   Men, 55 to 64 years     71.4
# 176  414       38                Idaho Women, 55 to 64 years     60.8
# 183  440       31             Illinois   Men, 55 to 64 years     63.4
# 190  447       38             Illinois Women, 55 to 64 years     59.7
# 197  473       31              Indiana   Men, 55 to 64 years     60.8
# 204  480       38              Indiana Women, 55 to 64 years     52.7
# 211  506       31                 Iowa   Men, 55 to 64 years     76.3
# 218  513       38                 Iowa Women, 55 to 64 years     68.2
# 225  539       31               Kansas   Men, 55 to 64 years     74.4
# 232  546       38               Kansas Women, 55 to 64 years     64.9
# 239  572       31             Kentucky   Men, 55 to 64 years     58.3
# 246  579       38             Kentucky Women, 55 to 64 years     51.4
# 253  604       31            Louisiana   Men, 55 to 64 years     64.5
# 260  611       38            Louisiana Women, 55 to 64 years     46.1
# 267  633       31                Maine   Men, 55 to 64 years     69.9
# 274  640       38                Maine Women, 55 to 64 years     63.2
# 281  666       31             Maryland   Men, 55 to 64 years     71.3
# 288  673       38             Maryland Women, 55 to 64 years     64.5
# 295  699       31        Massachusetts   Men, 55 to 64 years     68.2
# 302  706       38        Massachusetts Women, 55 to 64 years     62.8
# 309  732       31             Michigan   Men, 55 to 64 years     55.8
# 676 1559       38        West Virginia Women, 55 to 64 years     51.8
# 683 1585       31            Wisconsin   Men, 55 to 64 years     70.6
# 690 1592       38            Wisconsin Women, 55 to 64 years     62.8
# 697 1616       31              Wyoming   Men, 55 to 64 years     70.7
# 704 1623       38              Wyoming Women, 55 to 64 years     61.9
#     unemp_rate
# 6          4.1
# 13         2.2
# 19         6.5
# 24         4.5
# 30         4.1
# 37         5.5
# 44         5.5
# 50         5.4
# 57         7.5
# 64         6.3
# 71         6.4
# 78         5.9
# 85         5.7
# 92         6.5
# 99         3.4
# 106        5.2
# 113        9.4
# 120        9.4
# 127        6.5
# 134        6.1
# 141        3.1
# 148        6.1
# 155        5.3
# 162        4.8
# 169        4.7
# 176        4.3
# 183        8.8
# 190        4.5
# 197        6.0
# 204        4.3
# 211        2.3
# 218        3.9
# 225        3.9
# 232        4.6
# 239        4.0
# 246        3.8
# 253        3.2
# 260        7.2
# 267        4.3
# 274        3.3
# 281        5.4
# 288        4.0
# 295        6.8
# 302        3.7
# 309        8.2
# 316        5.4
# 323        4.4
# 330        3.6
# 336        4.3
# 343        4.0
# 350        4.3
# 357        5.8
# 364        5.4
# 370        3.9
# 377        1.4
# 384        2.9
# 391       10.4
# 398        7.5
# 405        4.7
# 412        2.8
# 419        6.3
# 426        5.6
# 433        5.9
# 440        5.7
# 447        6.5
# 454        4.6
# 461        5.2
# 468        5.2
# 475        2.3
# 481        2.0
# 488        4.6
# 495        5.3
# 502        2.6
# 508        2.4
# 515        5.1
# 522        4.9
# 529        5.7
# 536        5.7
# 543        8.0
# 550        7.2
# 557        3.6
# 564        6.6
# 571        3.0
# 578        1.7
# 585        4.8
# 592        4.7
# 599        4.6
# 606        4.8
# 613        2.8
# 620        3.1
# 627        4.0
# 634        2.0
# 641        3.9
# 648        3.8
# 655        6.1
# 662        2.8
# 669        5.1
# 676        3.4
# 683        5.8
# 690        3.5
# 697        3.7
# 704        3.8

# %%
# %%R -h 1000  -w 1000
#
# bigA=do.call(rbind, A)
# bigA$Age=gsub(".*, ", "", bigA$group)
# bigA$Gender=gsub(", .*", "", bigA$group)
#
# p <- ggplot(bigA, aes(x = factor(Age), y = emp_rate, color = Gender)) + geom_boxplot() + geom_jitter() + ggtitle("Employment Rate by Age Groups") +
#     theme(axis.text.x = element_text(angle = 90, hjust = 1)) + xlab("Age Groups") + ylab("Employment Rate")
# print(p)

# %%
# %%R -h 1000  -w 1000
#
#
# p2 <- ggplot(bigA, aes(x = factor(Age), y = unemp_rate, color = Gender)) + geom_boxplot() + geom_jitter() + ggtitle("Unemployment Rate by Age Groups") +
#     theme(axis.text.x = element_text(angle = 90, hjust = 1)) + xlab("Age Groups") + ylab("Unemployment Rate")
# print(p2)

# %%
# %%R
#
#
# race2013=read.csv('../data1/cleaned/race2013.csv',header=T)
# i=sapply(race2013, is.factor)
# race2013[i]=lapply(race2013[i],as.character)
# race2013=race2013[complete.cases(race2013),]
#
#
# R1=subset(race2013,grp_code==5|grp_code==6)
# R2=subset(race2013,grp_code==8|grp_code==9)
# R3=subset(race2013,grp_code==14|grp_code==15)
#
# R=list(R1,R2,R3)
#
# print(head(R[1]))
# Out:
# [[1]]
#        X grp_code                state        group emp_rate unemp_rate
# 1      5        5              Alabama   White, men     63.9        5.4
# 2      6        6              Alabama White, women     50.1        5.1
# 6     37        5               Alaska   White, men     67.9        6.5
# 7     38        6               Alaska White, women     61.1        4.3
# 10    63        5              Arizona   White, men     61.7        7.2
# 11    64        6              Arizona White, women     49.5        7.2
# 16    96        5             Arkansas   White, men     59.9        6.5
# 17    97        6             Arkansas White, women     48.4        6.2
# 22   128        5           California   White, men     64.9        8.6
# 23   129        6           California White, women     50.4        8.6
# 28   161        5             Colorado   White, men     69.8        6.7
# 29   162        6             Colorado White, women     58.8        5.9
# 34   194        5          Connecticut   White, men     64.9        7.3
# 35   195        6          Connecticut White, women     55.4        6.7
# 40   227        5             Delaware   White, men     61.5        5.7
# 41   228        6             Delaware White, women     50.8        6.2
# 46   260        5 District of Columbia   White, men     81.6        4.5
# 47   261        6 District of Columbia White, women     75.0        3.2
# 52   293        5              Florida   White, men     61.9        6.3
# 53   294        6              Florida White, women     50.2        5.8
# 58   326        5              Georgia   White, men     67.1        5.3
# 59   327        6              Georgia White, women     49.1        6.5
# 64   359        5               Hawaii   White, men     65.3        4.3
# 65   360        6               Hawaii White, women     49.2        5.0
# 68   390        5                Idaho   White, men     67.4        5.6
# 69   391        6                Idaho White, women     53.0        6.7
# 72   420        5             Illinois   White, men     66.5        8.7
# 73   421        6             Illinois White, women     56.0        7.1
# 78   453        5              Indiana   White, men     65.1        6.9
# 79   454        6              Indiana White, women     52.7        6.8
# 84   486        5                 Iowa   White, men     71.0        4.8
# 85   487        6                 Iowa White, women     62.9        4.1
# 90   519        5               Kansas   White, men     69.6        5.4
# 91   520        6               Kansas White, women     60.2        5.0
# 96   552        5             Kentucky   White, men     60.7        7.9
# 97   553        6             Kentucky White, women     50.7        7.3
# 102  585        5            Louisiana   White, men     67.1        5.1
# 103  586        6            Louisiana White, women     50.5        4.7
# 107  617        5                Maine   White, men     64.5        7.1
# 108  618        6                Maine White, women     58.2        6.1
# 109  646        5             Maryland   White, men     69.0        6.1
# 110  647        6             Maryland White, women     57.9        4.5
# 115  679        5        Massachusetts   White, men     64.6        7.0
# 116  680        6        Massachusetts White, women     57.1        6.0
# 121  712        5             Michigan   White, men     62.1        8.0
# 122  713        6             Michigan White, women     51.1        6.8
# 127  745        5            Minnesota   White, men     70.9        4.8
# 128  746        6            Minnesota White, women     62.7        3.7
# 133  778        5          Mississippi   White, men     61.5        5.5
# 134  779        6          Mississippi White, women     47.3        6.7
# 138  809        5             Missouri   White, men     67.1        5.8
# 139  810        6             Missouri White, women     54.7        6.0
# 144  842        5              Montana   White, men     64.8        5.5
# 145  843        6              Montana White, women     57.9        4.0
# 146  869        5             Nebraska   White, men     75.4        3.6
# 147  870        6             Nebraska White, women     64.2        3.4
# 152  902        5               Nevada   White, men     65.0        9.1
# 153  903        6               Nevada White, women     52.7        8.8
# 158  935        5        New Hampshire   White, men     70.0        5.7
# 159  936        6        New Hampshire White, women     61.8        4.6
# 162  966        5           New Jersey   White, men     65.1        8.1
# 163  967        6           New Jersey White, women     53.6        6.9
# 168  999        5           New Mexico   White, men     60.3        6.8
# 169 1000        6           New Mexico White, women     47.5        5.7
# 172 1030        5             New York   White, men     63.8        7.0
# 173 1031        6             New York White, women     53.6        6.2
# 178 1063        5       North Carolina   White, men     65.5        6.2
# 179 1064        6       North Carolina White, women     50.3        6.8
# 184 1096        5         North Dakota   White, men     77.5        2.7
# 185 1097        6         North Dakota White, women     67.9        1.7
# 186 1122        5                 Ohio   White, men     64.0        7.7
# 187 1123        6                 Ohio White, women     55.1        5.7
# 192 1155        5             Oklahoma   White, men     67.6        5.0
# 193 1156        6             Oklahoma White, women     51.0        4.3
# 198 1187        5               Oregon   White, men     60.7        8.3
# 199 1188        6               Oregon White, women     51.4        7.1
# 202 1218        5         Pennsylvania   White, men     65.4        7.2
# 203 1219        6         Pennsylvania White, women     54.3        6.2
# 208 1251        5         Rhode Island   White, men     63.8        9.8
# 209 1252        6         Rhode Island White, women     55.8        7.5
# 214 1284        5       South Carolina   White, men     62.5        6.1
# 215 1285        6       South Carolina White, women     49.0        5.8
# 220 1317        5         South Dakota   White, men     73.1        2.9
# 221 1318        6         South Dakota White, women     64.1        2.6
# 223 1346        5            Tennessee   White, men     63.1        6.8
# 224 1347        6            Tennessee White, women     48.4        6.4
# 229 1379        5                Texas   White, men     70.3        5.5
# 230 1380        6                Texas White, women     52.4        5.7
# 235 1412        5                 Utah   White, men     75.5        4.0
# 236 1413        6                 Utah White, women     57.6        4.3
# 239 1442        5              Vermont   White, men     69.0        4.5
# 240 1443        6              Vermont White, women     62.5        3.8
# 241 1469        5             Virginia   White, men     70.4        4.4
# 242 1470        6             Virginia White, women     56.5        4.9
# 247 1502        5           Washington   White, men     64.7        7.1
# 248 1503        6           Washington White, women     54.2        6.4
# 253 1535        5        West Virginia   White, men     54.6        7.8
# 254 1536        6        West Virginia White, women     45.7        5.3
# 257 1565        5            Wisconsin   White, men     69.2        6.6
# 258 1566        6            Wisconsin White, women     60.9        4.9
# 263 1598        5              Wyoming   White, men     71.7        4.5
# 264 1599        6              Wyoming White, women     58.1        4.2

# %%
# %%R -h 1000  -w 1000
#
# bigR=do.call(rbind, R)
# bigR$Gender=gsub(".*, ", "", bigR$group)
# bigR$Race=gsub(", .*", "", bigR$group)
# print(head(bigR))
#
# q <- ggplot(bigR, aes(x = factor(Race), y = emp_rate, color = Gender)) + geom_boxplot() + geom_jitter() + ggtitle("Employment Rate by Race Groups") + xlab("Race Groups") + ylab("Employment Rate")
# print(q)
# Out:
#     X grp_code   state        group emp_rate unemp_rate Gender  Race
# 1   5        5 Alabama   White, men     63.9        5.4    men White
# 2   6        6 Alabama White, women     50.1        5.1  women White
# 6  37        5  Alaska   White, men     67.9        6.5    men White
# 7  38        6  Alaska White, women     61.1        4.3  women White
# 10 63        5 Arizona   White, men     61.7        7.2    men White
# 11 64        6 Arizona White, women     49.5        7.2  women White

# %%
# %%R -h 1000  -w 1000
#
#
#
# q2 <- ggplot(bigR, aes(x = factor(Race), y = unemp_rate, color = Gender)) + geom_boxplot() + geom_jitter() + ggtitle("Unemployment Rate by Race Groups") + xlab("Race Groups") + ylab("Unemployment Rate")
# print(q2)

# %% [markdown]
# want to compare California Employment rate with the rates in other states & predict its trend according to the data in the past 10 years

# %% [markdown]
# We take the average of all males and females in all states and compare them with the average of males and females in California:

# %%
# %%R   -h 1000  -w  1000
#
# print(head(gen2013))
# gen2013m=subset(gen2013, group=="Men")
# gen2013w=subset(gen2013, group=="Women")
# MenAvg=mean(gen2013m[ ,"emp_rate"], na.rm = TRUE)
# WomenAvg=mean(gen2013w[ ,"emp_rate"], na.rm=TRUE)
# print(MenAvg)
#
# gen2013m$difference=gen2013m$emp_rate-MenAvg
# gen2013w$differencen=gen2013w$emp_rate-WomenAvg
# print(head(gen2013m))
# plot(gen2013m$state,gen2013m$difference, las=2, xlab="state", main="Male: Difference between California Employment Rate and Average Employment Rate")
# plot(gen2013w$state,gen2013w$difference, las=2, xlab="state", main="Female: Difference between California Employment Rate and Average Employment Rate")
# Out:
#    X grp_code   state group emp_rate unemp_rate
# 1  2        2 Alabama   Men     59.2        7.0
# 2  3        3 Alabama Women     49.3        6.8
# 3 34        2  Alaska   Men     66.7        7.7
# 4 35        3  Alaska Women     59.6        5.3
# 5 60        2 Arizona   Men     60.4        8.2
# 6 61        3 Arizona Women     49.0        7.8
# [1] 65.03725
#      X grp_code      state group emp_rate unemp_rate difference
# 1    2        2    Alabama   Men     59.2        7.0  -5.837255
# 3   34        2     Alaska   Men     66.7        7.7   1.662745
# 5   60        2    Arizona   Men     60.4        8.2  -4.637255
# 7   93        2   Arkansas   Men     58.7        7.9  -6.337255
# 9  125        2 California   Men     64.0        9.1  -1.037255
# 11 158        2   Colorado   Men     69.3        6.9   4.262745

# %%
# %%R
# gencal=read.csv('../data1/cleaned/gencal.csv',header=T)
# print(head(gencal))
# Out:
#      X year grp_code      state group emp_rate unemp_rate
# 1  189 2004        2 California   Men     69.2        6.3
# 2  190 2004        3 California Women     54.1        6.0
# 3 2608 2005        2 California   Men     70.4        5.2
# 4 2609 2005        3 California Women     54.0        5.4
# 5 5016 2006        2 California   Men     70.4        4.7
# 6 5017 2006        3 California Women     53.9        5.0

# %%
# %%R
# gencalm=subset(gencal, group=='Men')
# print(head(gencalm))
# plot(gencalm$year,gencalm$emp_rate, xlab="year", ylab="Employment Rate")
# lines(gencalm$year,gencalm$emp_rate)
# title(main="Employment Rate Change in the last 10 years in California")
# Out:
#        X year grp_code      state group emp_rate unemp_rate
# 1    189 2004        2 California   Men     69.2        6.3
# 3   2608 2005        2 California   Men     70.4        5.2
# 5   5016 2006        2 California   Men     70.4        4.7
# 7   7404 2007        2 California   Men     70.2        5.5
# 9   9792 2008        2 California   Men     68.7        7.4
# 11 12196 2009        2 California   Men     63.8       12.3
